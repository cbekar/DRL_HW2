# %% [markdown]
# # Homework 2
#
# In this homework, you will be implementing Deep Q Networks and Asynchronous Advantage Actor-Critic models and use them in two of the Atari games and simple gym environments. You will need to fill the missing parts in the modules and then run your tests in the notebook.

# %% [markdown]
# ## 1) Deep Q Networks (50)
#
# As seen in the class, DQN has two main features, namely target networks and replay buffer. However, additional improvements have been introduced since the first release of DQN.
#
# - [Prioritized Replay Buffer](https://arxiv.org/pdf/1509.06461.pdf)
# - [Double Deep Q Networks](https://arxiv.org/pdf/1511.05952.pdf)
# - [Dueling Deep Q Networks](https://arxiv.org/pdf/1511.06581.pdf)
#
# After implementing these methods, you can compare combined algorithm with the vanilla DQN. For comparison you will be using two [gym](https://gym.openai.com/) environments.
# - [Lunar Lander](LunarLander-v2)
# - [Pong](https://gym.openai.com/envs/Pong-v0/)

# %%
# In order to use modified modules without restarting
# %load_ext autoreload
# %autoreload 2

# %%
import torch; 
from gym.version import VERSION
print(torch.__version__)
print(VERSION)
# %load_ext line_profiler

# %%
import gym
import numpy as np
import torch

from blg604ehw2.dqn import episodic_test
from blg604ehw2.dqn import episodic_train

from blg604ehw2.network import Network
from blg604ehw2.network import FcNet
from blg604ehw2.network import DuelingHead
from blg604ehw2.network import SimpleHead

from blg604ehw2.utils import comparison
from blg604ehw2.utils import LoadingBar

# %% [markdown]
# ### Lunar Lander with DQN (15)

# %%
def traindqn(env, agent, args, test_rate=1):
    bar = LoadingBar(args.episode, "Episode")
    #agent.to(args.device)
    agent.device = args.device
    epsilons = np.linspace(args.max_epsilon , args.min_epsilon, num=args.episode)
    time_step = 0
    rewards = []
    td_errors = []

    best_model = None
    best_rewards = []
    best_reward = -np.inf
    #import pdb;pdb.set_trace()
    for eps in range(args.episode):
        ### YOUR CODE HERE ###
        time_step, td_error = episodic_train(env, agent, args, epsilons[eps])
        if eps % test_rate == 0:
            reward = 0
            for it in range(test_rate):
                reward += episodic_test(env, agent, args)
            reward /= test_rate
            best_reward = reward if best_reward < reward else best_reward
        best_rewards.append(best_reward)
        td_errors.append(td_error)
        rewards.append(reward)
        best_model = agent if best_reward == reward else best_model
        
        ###       END      ###
        bar.progress(eps, best_reward)
        
    bar.success(best_reward)
    return rewards, best_rewards, td_errors, time_step, best_model

# %% [markdown]
# ### a) Vanilla DQN

# %%
from blg604ehw2.dqn import DQN
from blg604ehw2.dqn import ArgsDQN

# Set the environment name, you can try differnet environments.
envname = "LunarLander-v2"

# Hyperparameters for the traning
# You need to finetune some of the  hyperparameters!
env = gym.make(envname)
dqn_args = ArgsDQN(
        **dict(
            env_name=envname,           # Name of the environment
            nstates=env.observation_space.shape,  
            nact=env.action_space.n,    # Number of actions
            buffersize=20000,           # Size of the replay buffer
            max_epsilon=0.9,            # Starting value of the epsilon
            min_epsilon=0.1,            # Convergence value of the epsilon
            target_update_period=50,    # Update period of the target network
            gamma=0.99,                 # Discount rate
            lr=0.001,                   # Learning rate
            device="cuda",              # Device name
            batch_size=128,             # Batch size
            episode=10,             # Number of episodes for training
            max_eps_len=600          # Maximum number of time steps in an episode
        )
    )

def dqn_agent():
    # Network construction
    feature_net = FcNet(env.observation_space.shape[0], 128)
    head_net = SimpleHead(env.action_space.n, 128)
    valuenet = Network(feature_net, head_net)
    
    # Initialize and return agent
    return DQN(
        dev = dqn_args.device,
        valuenet = valuenet,
        nact = env.action_space.n,
        lr = dqn_args.lr,
        buffer_capacity = dqn_args.buffersize,
        target_update_period = dqn_args.target_update_period
        )

# %%
REPEAT = 1
lunar_dqn = []
#with torch.autograd.profiler.profile(use_cuda=True) as prof:
for r in range(REPEAT):
    env = gym.make(dqn_args.env_name)
    agent = dqn_agent()
    lunar_dqn.append(traindqn(env, agent, dqn_args, test_rate=5))

# %%
prof.table(sort_by="cuda_time_total")
prof.key_averages()
prof.export_chrome_trace("/home/cbekar/Desktop/trace")

# %%
    plot_texts = [
    [
        "Episodic Reward",
        "episode",
        "reward"
    ],
    [
        "Episodic Best Reward",
        "episode",
        "reward"
    ],
    [
        "Td Error",
        "episode",
        "td"
    ]
]

# %%
comparison((lunar_dqn, "DQN"), texts = plot_texts)

# %%
# Remember that due to the stochasticty of the
# environment it may perform differently for each run

# Assuming ddpdqn works better in your environment as it should be
#import pdb;pdb.set_trace()
best_agent_index = max(range(len(lunar_dqn)), key = lambda i: lunar_dqn[i][1][-1])
best_agent_state_dict = lunar_dqn[best_agent_index][4]
best_agent = dqn_agent()
########!best_agent.load_state_dict(best_agent_state_dict)

# Monitor saves the mp4 files under "monitor" folder.
monitor_path = "LunarLander/DQN/" + str(dqn_args.episode) + " episode"
model_path = "monitor/LunarLander/model_state_dict"
episodic_test(agent=lunar_dqn[best_agent_index][4], env=gym.make(dqn_args.env_name), args=dqn_args, monitor_path=monitor_path)
torch.save(best_agent_state_dict, model_path)

# %%
monitor_path = "LunarLander/DQN/" + str(dqn_args.episode) + " episode"
model_path = "model_state_dict"
best_agent = torch.load(model_path)
episodic_test(agent=best_agent, env=gym.make(dqn_args.env_name), args=dqn_args, monitor_path=monitor_path)

# %%
env.close()

# %% [markdown]
# ### b) Dueling Double Prioritized DQN (15)

# %%
from blg604ehw2.dqn import DuelingDoublePrioritizedDQN
from blg604ehw2.dqn import ArgsDDPQN


# Hyperparameters for the traning
# You need to finetune some of the  hyperparameters!
envname = "LunarLander-v2"
env = gym.make(envname)
ddpdqn_args = ArgsDDPQN(
        **dict(
            env_name=envname,           # Name of the environment
            nstates=env.observation_space.shape,
            nact=env.action_space.n,    # Number of actions
            buffersize=20000,           # Size of the replay buffer
            max_epsilon=0.9,            # Starting value of the epsilon
            min_epsilon=0.1,            # Convergence value of the epsilon
            target_replace_period=50,   # Update period of the target network
            gamma=0.99,                 # Discount rate
            lr=0.001,                   # Learning rate
            device="cuda",               # Device name
            batch_size=128,             # Batch size
            episode=10,                 # Number of episodes for training
            max_eps_len=400             # Maximum number of time steps in an episode
        )
    )

def ddpdqn_agent():
    # Network construction
    feature_net = FcNet(env.observation_space.shape[0], 128)
    head_net = DuelingHead(env.action_space.n, 128)
    valuenet = Network(feature_net, head_net)

    # Initialize agent
    return DuelingDoublePrioritizedDQN(
        dev = ddpdqn_args.device,
        valuenet = valuenet,
        nact = env.action_space.n,
        lr = ddpdqn_args.lr,
        buffer_capacity = ddpdqn_args.buffersize,
        target_replace_period = ddpdqn_args.target_replace_period,
        gamma = ddpdqn_args.gamma
    )

# %%
REPEAT = 1
lunar_ddpdqn = []
for r in range(REPEAT):
    env = gym.make(ddpdqn_args.env_name)
    agent = ddpdqn_agent()
    lunar_ddpdqn.append(traindqn(env, agent, ddpdqn_args, test_rate=5))

# %%
comparison((lunar_ddpdqn, "DDPDQN"), (lunar_dqn, "DQN"), texts = plot_texts)

# %% [markdown]
# You may compare these improvements by themselves if you want to. See which one of them makes the most improvement for the Lunar Lander environment.(optional)

# %% [markdown]
# #### Let's visualize the best agent

# %%
# Remember that due to the stochasticty of the
# environment it may perform differently for each run

# Assuming ddpdqn works better in your environment as it should be
best_agent_index = max(range(len(lunar_ddpdqn)), key = lambda i: lunar_ddpdqn[i][1][-1])
best_agent_state_dict = lunar_ddpdqn[best_agent_index][4]
best_agent = ddpdqn_agent()
best_agent.load_state_dict(best_agent_state_dict)

# Monitor saves the mp4 files under "monitor" folder.
monitor_path = "LunarLander/" + str(ddpdqn_args.episode) + " episode"
model_path = "monitor/LunarLander/model_state_dict"
episodic_test(agent=best_agent, env=gym.make(ddpdqn_args.env_name), args=ddpdqn_args, monitor_path=monitor_path)
torch.save(best_agent_state_dict, model_path)

# %% [markdown]
# ### Pong with Dueling Double Prioritized DQN (20)
# - This may take long time

# %%
from blg604ehw2.atari_wrapper import ClipRewardEnv
from blg604ehw2.atari_wrapper import FrameStack
from blg604ehw2.atari_wrapper import EpisodicLifeEnv
from blg604ehw2.atari_wrapper import WarpFrame
from blg604ehw2.atari_wrapper import ScaledFloatFrame

from blg604ehw2.network import Cnn

envname = "PongNoFrameskip-v4" # Should be without frameskips

# Wrapped atari environment.
# It is important to use these wrappers in order
# to simplfy learning. In their Nature paper,
# Deepmind used some of them to achive those
# results. It is good to check them and see 
# what do they do.
def pongenv():
    env = gym.make(envname)
    env = ClipRewardEnv(env)            # Clip the reward between -1 and 1
    env = WarpFrame(env)                # Downsample rgb (210, 160, 3) images to gray images (84, 84)
    env = EpisodicLifeEnv(env)          # Terminate the environment after a live is lost
    env = FrameStack(env, k=4)          # Stack consecutive frames as a single state
    return env

# Hyperparameters for the traning
# This time parameter tunning is even more important!
# If you have access to a gpu use it! Set the device accordingly.
env = pongenv()
pong_args = ArgsDDPQN(
        **dict(
            env_name=envname,           # Name of the environment
            nstates=env.observation_space,
            nact=env.action_space.n,    # Number of actions
            buffersize=1000,          # Size of the replay buffer
            max_epsilon=0.9,            # Starting value of the epsilon
            min_epsilon=0.1,            # Convergence value of the epsilon
            target_replace_period=100,  # Update period of the target network
            gamma=0.97,                 # Discount rate
            lr=0.0002,                  # Learning rate
            device="cuda",              # Device name
            batch_size=128,             # Batch size
            episode=10,               # Number of episodes for training
            max_eps_len=100            # Maximum number of time steps in an episode
        )
    )

def pong_agent():
    # Network construction
    feature_net = Cnn(4, 512)
    head_net = DuelingHead(env.action_space.n, 512)
    valuenet = Network(feature_net, head_net)

    # Initialize agent
    return DuelingDoublePrioritizedDQN(
        dev = pong_args.device,
        valuenet = valuenet,
        nact = env.action_space.n,
        lr = pong_args.lr,
        buffer_capacity = pong_args.buffersize,
        target_replace_period = pong_args.target_replace_period
    )

# %%
REPEAT = 1 # Assign 1 if you dont want to train more than one
pong_ddpdqn = []
for r in range(REPEAT):
    env = pongenv()
    agent = pong_agent()
    pong_ddpdqn.append(traindqn(env, agent, pong_args, test_rate=3))

# %%
comparison((pong_ddpdqn, "PONG"), texts = plot_texts)

# %%
best_agent_index = max(range(len(pong_ddpdqn)), key = lambda i: pong_ddpdqn[i][1][-1])
best_agent_state_dict = pong_ddpdqn[best_agent_index][4]
best_agent = pong_agent() 
#best_agent.load_state_dict(best_agent_state_dict)

# Monitor saves the mp4 files under "monitor" folder.
monitor_path = "Pong/" + str(pong_args.episode) + " episode"
model_path = "monitor/Pong/model_state_dict"
episodic_test(agent=pong_ddpdqn[best_agent_index][4], env=pongenv(), args=pong_args, monitor_path=monitor_path)
torch.save(best_agent_state_dict, model_path)

# %% [markdown]
# ## 2) Asynchronous Advantage Actor-Critic (50)
# [A3C](https://arxiv.org/abs/1602.01783) is a policy gradinet algorithm which is based on asynchronous updates of paralel agents.
# You will be testing your agent in:
#
# - [Bipedal Walker](https://gym.openai.com/envs/BipedalWalker-v2/)
# - [Breakout](https://gym.openai.com/envs/Breakout-v0/)

# %% [markdown]
# ### a) Bipedal Walker with Asynchronous Advantage Actor-Critic (20)
# It is important to test your implementation with a simpler enviroment like BipedalWalker before trying Breakout.
# It is highly recommended to check the pseudocode in the paper's appendix.
#
# The implementation works as follows:
#
#     - Create a global agent which's paremeters are in the shared memory.
#     - Create multiple worker processes. That performs:
#         - Gradient calculation with the transition it observed
#         - Update the global agent with the gradients
#         - Synchronize with the global agent
#     - Create a test process that evaluates the performance of the global agent over the course of the training
#     - Run these workers asynchronously

# %%
# In order to use modified modules without restarting
# %load_ext autoreload
# %autoreload 2

# %%
import gym
from collections import namedtuple
import torch.multiprocessing as mp 

from blg604ehw2.network import FcNet
from blg604ehw2.network import ContinuousDistHead
from blg604ehw2.network import Network

from blg604ehw2.a3c import ContinuousA3c
from blg604ehw2.a3c import SharedAdam
from blg604ehw2.a3c import train_worker
from blg604ehw2.a3c import test_worker
from blg604ehw2.a3c import A3C_args


# Bipedal Walker environment is similar to Lunar Lander
# State space is a vector of length 24 and there are
# 4 actions
envname = "BipedalWalker-v2"

# Logger is a named tuple of shared lists integer and a model
# It is necessary to have a shared object since it can be used
# by many processes
Logger = namedtuple("Logger", "eps_reward best_reward best_model time_steps time")

# Hyperparameters, again tunning is necessary but optional.
a3c_args = A3C_args(
    **dict(
        maxtimestep=100000,     # Number of time steps for training
        maxlen=600,             # Maximum length of an episode
        nstep=20,               # Bootsrapping length (n-step td)
        gamma=0.98,             # Discount rate
        lr=0.0001,              # Learning rate
        beta=0.01,              # Entropy regularization constant
        device="cpu",           # Device
    )
)

# Agent generating function
def a3c_agent():
    feature_net = FcNet(24)
    head_net = ContinuousDistHead(128, 4)
    network = Network(feature_net, head_net)
    agent = ContinuousA3c(network)
    agent.device = a3c_args.device
    return agent

# Environment generating function
# You can use RewardClip wrapper
def walker_env():
    env =  gym.make(envname)
    return env

# %%
### Main cell for Bipedal Walker ###

# Number of training workers
N_PROCESSES = mp.cpu_count()

# Global agent that will be used for synchronization.
global_agent = a3c_agent()
global_agent.share_memory()         # Make sure it is in the shared memory!

# Shared optimizer, since the optimizer has its own parameters
# they need to be in the shared memory as well.
sharedopt = SharedAdam(global_agent.parameters(), lr=a3c_args.lr)

# Another agent for logging purposes
best_agent = a3c_agent()
best_agent.share_memory()

# Logger
# Manager controls another process(server process) to share
# objects between multiple processes via proxies.
# Please read https://docs.python.org/3.7/library/multiprocessing.html
# for more information.
manager = mp.Manager()
logger = Logger(
    manager.list(),
    manager.list(),
    best_agent,
    manager.list(),
    manager.Value("i", 0)
)
logger.time_steps.append(0)
for t in range(a3c_args.maxtimestep):
    logger.eps_reward.append(None)
    logger.best_reward.append(None)
    
# Lock is not necessary
lock = mp.Lock()

# Start by creating a test worker
processes = []
process = mp.Process(target=test_worker,
                     args=(a3c_args, global_agent, walker_env, a3c_agent, lock, logger,\
                           None,False))
# test_worker(a3c_args, global_agent, walker_env, a3c_agent, N_PROCESSES, logger)
# train_worker(a3c_args, global_agent, sharedopt, walker_env, a3c_agent, 0, N_PROCESSES, logger)
process.start()
processes.append(process)

# # Train workers
for t in range(N_PROCESSES):
    process = mp.Process(target=train_worker,
                         args=(a3c_args, global_agent, sharedopt, walker_env, a3c_agent, t, N_PROCESSES, logger))
    process.start()
    processes.append(process)
    
# Wait until all done
for p in processes:
    p.join()

# %%
# Plot the rewards from the logger
import matplotlib.pyplot as plt
plt.title("A3C Walker Best Rewards")
plt.ylabel("reward")
plt.xlabel("time steps")
plt.plot(list(logger.time_steps), list(logger.best_reward))

# %% [markdown]
# ### b) Breakout with Asynchronous Advantage Actor-Critic (30)
#
# - It takes a lot of time so be prepared.

# %%
# In order to use modified modules without restarting
# %load_ext autoreload
# %autoreload 2

# %%
import gym
import torch
from blg604ehw2.atari_wrapper import ClipRewardEnv
from blg604ehw2.atari_wrapper import FrameStack
from blg604ehw2.atari_wrapper import EpisodicLifeEnv
from blg604ehw2.atari_wrapper import WarpFrame
from blg604ehw2.atari_wrapper import ScaledFloatFrame

from blg604ehw2.network import Cnn
from blg604ehw2.network import DiscreteDistHead
from collections import namedtuple
import torch.multiprocessing as mp 
from blg604ehw2.a3c import DiscreteA3c
from blg604ehw2.a3c import A3C_args
from blg604ehw2.network import Network
from blg604ehw2.a3c import SharedAdam
from blg604ehw2.a3c import train_worker
from blg604ehw2.a3c import test_worker
# Breakout Environment
envname = "Breakout-v4"
Logger = namedtuple("Logger", "eps_reward best_reward best_model time_steps time")

# Hyperparameters
breakout_args = A3C_args(
    **dict(
        maxtimestep=40000000,
        maxlen=2000,
        nstep=20,
        gamma=0.98,
        lr=0.00003,
        beta=0.01,
        device="cpu",
    )
)

def breakout_agent():
    feature_net = Cnn(4, 512) # 4 channel size because of the StackFrame buffer
    head_net = DiscreteDistHead(512, 4) # 4 output because of the environment's action space
    network = Network(feature_net, head_net)
    agent = DiscreteA3c(network)
    agent.device = breakout_args.device
    return agent

def breakout_env():
    env = gym.make(envname)
    env = ClipRewardEnv(env)            # Clip the reward between -1 and 1
    env = WarpFrame(env)                # Downsample rgb (210, 160, 3) images to gray images (84, 84)
    env = EpisodicLifeEnv(env)          # Terminate the environment after a live is lost
    env = FrameStack(env, k=4)          # Stack consecutive frames as a single state
    return env

# %%
### Main cell for Breakout ###

N_PROCESSES = mp.cpu_count()

global_agent = breakout_agent()
global_agent.share_memory()
sharedopt = SharedAdam(global_agent.parameters(), lr=breakout_args.lr)

best_agent = breakout_agent()
best_agent.share_memory()

# Try to use one manager
manager = mp.Manager()
logger = Logger(
    manager.list(),
    manager.list(),
    best_agent,
    manager.list(),
    manager.Value("i", 0)
)
logger.time_steps.append(0)
for t in range(N_PROCESSES):
    logger.eps_reward.append(None)
    logger.best_reward.append(None)
lock = mp.Lock()

processes = []

process = mp.Process(target=test_worker,
                     args=(breakout_args, global_agent, breakout_env, breakout_agent, lock, logger))
# train_worker(breakout_args, global_agent, sharedopt, breakout_env, breakout_agent, 0, N_PROCESSES, logger)
# test_worker(breakout_args, global_agent, breakout_env, breakout_agent, N_PROCESSES, logger)
process.start()
processes.append(process)
for t in range(N_PROCESSES):
    process = mp.Process(target=train_worker,
                         args=(breakout_args, global_agent, sharedopt, breakout_env, breakout_agent, t, N_PROCESSES, logger))
    process.start()
    processes.append(process)
for p in processes:
    p.join()
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=40000000)))
# > /home/cbekar/Dropbox/Academic/PhD/Semesters/Spring19/RL/DRL/HWs/BLG604E-HW2-homework/DRL_HW2/blg604ehw2/a3c/train.py(116)test_worker()
# -> state = env.reset()
# (Pdb) c
# train steps 0 test steps 1 max reward 0.0
# train steps 0 test steps 2 max reward 0.0
# train steps 0 test steps 3 max reward 0.0
# train steps 0 test steps 4 max reward 0.0
# train steps 0 test steps 5 max reward 0.0
# train steps 0 test steps 6 max reward 0.0
# train steps 0 test steps 7 max reward 0.0
# train steps 0 test steps 8 max reward 0.0
# train steps 0 test steps 9 max reward 0.0
# train steps 0 test steps 10 max reward 0.0
# train steps 0 test steps 11 max reward 0.0
# train steps 0 test steps 12 max reward 0.0
# train steps 0 test steps 13 max reward 0.0
# train steps 0 test steps 14 max reward 0.0
# train steps 0 test steps 15 max reward 0.0
# train steps 0 test steps 16 max reward 0.0
# train steps 0 test steps 17 max reward 0.0
# train steps 0 test steps 18 max reward 0.0
# train steps 0 test steps 19 max reward 0.0
# train steps 0 test steps 20 max reward 0.0
# train steps 0 test steps 21 max reward 0.0
# train steps 0 test steps 22 max reward 0.0
# train steps 0 test steps 23 max reward 0.0
# train steps 0 test steps 24 max reward 0.0
# train steps 0 test steps 25 max reward 0.0
# train steps 0 test steps 26 max reward 0.0
# train steps 0 test steps 27 max reward 0.0
# train steps 0 test steps 28 max reward 0.0
# train steps 0 test steps 29 max reward 0.0
# train steps 0 test steps 30 max reward 0.0
# train steps 0 test steps 31 max reward 0.0
# train steps 0 test steps 32 max reward 0.0
# train steps 0 test steps 33 max reward 0.0
# train steps 0 test steps 34 max reward 0.0
# train steps 0 test steps 35 max reward 0.0
# train steps 0 test steps 36 max reward 0.0
# train steps 0 test steps 37 max reward 0.0
# train steps 0 test steps 38 max reward 0.0
# train steps 0 test steps 39 max reward 0.0
# train steps 0 test steps 40 max reward 0.0
# train steps 0 test steps 41 max reward 0.0
# train steps 0 test steps 42 max reward 0.0
# train steps 0 test steps 43 max reward 0.0
# train steps 0 test steps 44 max reward 0.0
# train steps 0 test steps 45 max reward 0.0
# train steps 0 test steps 46 max reward 0.0
# train steps 0 test steps 47 max reward 0.0
# train steps 0 test steps 48 max reward 0.0
# train steps 0 test steps 49 max reward 0.0
# train steps 0 test steps 50 max reward 0.0
# train steps 0 test steps 51 max reward 0.0
# train steps 0 test steps 52 max reward 0.0
# train steps 0 test steps 53 max reward 0.0
# train steps 0 test steps 54 max reward 0.0
# train steps 0 test steps 55 max reward 0.0
# train steps 0 test steps 56 max reward 0.0
# train steps 0 test steps 57 max reward 0.0
# train steps 0 test steps 58 max reward 0.0
# train steps 0 test steps 59 max reward 0.0
# train steps 0 test steps 60 max reward 0.0
# train steps 0 test steps 61 max reward 0.0
# train steps 0 test steps 62 max reward 0.0
# train steps 0 test steps 63 max reward 0.0
# train steps 0 test steps 64 max reward 0.0
# train steps 0 test steps 65 max reward 0.0
# train steps 0 test steps 66 max reward 0.0
# train steps 0 test steps 67 max reward 0.0
# train steps 0 test steps 68 max reward 0.0
# train steps 0 test steps 69 max reward 0.0
# train steps 0 test steps 70 max reward 0.0
# train steps 0 test steps 71 max reward 0.0
# train steps 0 test steps 72 max reward 0.0
# train steps 0 test steps 73 max reward 0.0
# train steps 0 test steps 74 max reward 0.0
# train steps 0 test steps 75 max reward 0.0
# train steps 0 test steps 76 max reward 0.0
# train steps 0 test steps 77 max reward 0.0
# train steps 0 test steps 78 max reward 0.0
# train steps 0 test steps 79 max reward 0.0
# train steps 0 test steps 80 max reward 0.0
# train steps 0 test steps 81 max reward 0.0
# train steps 0 test steps 82 max reward 0.0
# train steps 0 test steps 83 max reward 0.0
# train steps 0 test steps 84 max reward 0.0
# train steps 0 test steps 85 max reward 0.0
# train steps 0 test steps 86 max reward 0.0
# train steps 0 test steps 87 max reward 0.0
# train steps 0 test steps 88 max reward 0.0
# train steps 0 test steps 89 max reward 0.0
# train steps 0 test steps 90 max reward 0.0
# train steps 0 test steps 91 max reward 0.0
# train steps 0 test steps 92 max reward 0.0
# train steps 0 test steps 93 max reward 0.0
# train steps 0 test steps 94 max reward 0.0
# train steps 0 test steps 95 max reward 0.0
# train steps 0 test steps 96 max reward 0.0
# train steps 0 test steps 97 max reward 0.0
# train steps 0 test steps 98 max reward 0.0
# train steps 0 test steps 99 max reward 0.0
# train steps 0 test steps 100 max reward 0.0
# train steps 0 test steps 101 max reward 0.0
# train steps 0 test steps 102 max reward 0.0
# train steps 0 test steps 103 max reward 0.0
# train steps 0 test steps 104 max reward 0.0
# train steps 0 test steps 105 max reward 0.0
# train steps 0 test steps 106 max reward 0.0
# train steps 0 test steps 107 max reward 0.0
# train steps 0 test steps 108 max reward 0.0
# train steps 0 test steps 109 max reward 0.0
# train steps 0 test steps 110 max reward 0.0
# train steps 0 test steps 111 max reward 0.0
# train steps 0 test steps 112 max reward 0.0
# train steps 0 test steps 113 max reward 0.0
# train steps 0 test steps 114 max reward 0.0
# train steps 0 test steps 115 max reward 0.0
# train steps 0 test steps 116 max reward 0.0
# train steps 0 test steps 117 max reward 0.0
# train steps 0 test steps 118 max reward 0.0
# train steps 0 test steps 119 max reward 0.0
# train steps 0 test steps 120 max reward 0.0
# train steps 0 test steps 121 max reward 0.0
# train steps 0 test steps 122 max reward 0.0
# train steps 0 test steps 123 max reward 0.0
# train steps 0 test steps 124 max reward 0.0
# train steps 0 test steps 125 max reward 0.0
# train steps 0 test steps 126 max reward 0.0
# train steps 0 test steps 127 max reward 0.0
# train steps 0 test steps 128 max reward 0.0
# train steps 0 test steps 129 max reward 0.0
# train steps 0 test steps 130 max reward 0.0
# train steps 0 test steps 131 max reward 0.0
# train steps 0 test steps 132 max reward 0.0
# train steps 0 test steps 133 max reward 0.0
# train steps 0 test steps 134 max reward 0.0
# train steps 0 test steps 135 max reward 0.0
# train steps 0 test steps 136 max reward 0.0
# train steps 0 test steps 137 max reward 0.0
# train steps 0 test steps 138 max reward 0.0
# train steps 0 test steps 139 max reward 0.0
# train steps 0 test steps 140 max reward 0.0
# train steps 0 test steps 141 max reward 0.0
# train steps 0 test steps 142 max reward 0.0
# train steps 0 test steps 143 max reward 0.0
# train steps 0 test steps 144 max reward 0.0
# train steps 0 test steps 145 max reward 0.0
# train steps 0 test steps 146 max reward 0.0
# train steps 0 test steps 147 max reward 0.0
# train steps 0 test steps 148 max reward 0.0
# train steps 0 test steps 149 max reward 0.0
# train steps 0 test steps 150 max reward 0.0
# train steps 0 test steps 151 max reward 0.0
# train steps 0 test steps 152 max reward 0.0
# train steps 0 test steps 153 max reward 0.0
# train steps 0 test steps 154 max reward 0.0
# train steps 0 test steps 155 max reward 0.0
# train steps 0 test steps 156 max reward 0.0
# train steps 0 test steps 157 max reward 0.0
# train steps 0 test steps 158 max reward 0.0
# train steps 0 test steps 159 max reward 0.0
# train steps 0 test steps 160 max reward 0.0
# train steps 0 test steps 161 max reward 0.0
# train steps 0 test steps 162 max reward 0.0
# train steps 0 test steps 163 max reward 0.0
# train steps 0 test steps 164 max reward 0.0
# train steps 0 test steps 165 max reward 0.0
# train steps 0 test steps 166 max reward 0.0
# train steps 0 test steps 167 max reward 0.0
# train steps 0 test steps 168 max reward 0.0
# train steps 0 test steps 169 max reward 0.0
# train steps 0 test steps 170 max reward 0.0
# train steps 0 test steps 171 max reward 0.0
# train steps 0 test steps 172 max reward 0.0
# train steps 0 test steps 173 max reward 0.0
# train steps 0 test steps 174 max reward 0.0
# train steps 0 test steps 175 max reward 0.0
# train steps 0 test steps 176 max reward 0.0
# train steps 0 test steps 177 max reward 0.0
# train steps 0 test steps 178 max reward 0.0
# train steps 0 test steps 179 max reward 0.0
# train steps 0 test steps 180 max reward 0.0
# train steps 0 test steps 181 max reward 0.0
# train steps 0 test steps 182 max reward 0.0
# train steps 0 test steps 183 max reward 0.0
# train steps 0 test steps 184 max reward 0.0
# train steps 0 test steps 185 max reward 0.0
# train steps 0 test steps 186 max reward 0.0
# train steps 0 test steps 187 max reward 0.0
# train steps 0 test steps 188 max reward 0.0
# train steps 0 test steps 189 max reward 0.0
# train steps 0 test steps 190 max reward 0.0
# train steps 0 test steps 191 max reward 0.0
# train steps 0 test steps 192 max reward 0.0
# train steps 0 test steps 193 max reward 0.0
# train steps 0 test steps 194 max reward 0.0
# train steps 0 test steps 195 max reward 0.0
# train steps 0 test steps 196 max reward 0.0
# train steps 0 test steps 197 max reward 0.0
# train steps 0 test steps 198 max reward 0.0
# train steps 0 test steps 199 max reward 0.0
# train steps 0 test steps 200 max reward 0.0
# train steps 0 test steps 201 max reward 0.0
# train steps 0 test steps 202 max reward 0.0
# train steps 0 test steps 203 max reward 0.0
# train steps 0 test steps 204 max reward 0.0
# train steps 0 test steps 205 max reward 0.0
# train steps 0 test steps 206 max reward 0.0
# train steps 0 test steps 207 max reward 0.0
# train steps 0 test steps 208 max reward 0.0
# train steps 0 test steps 209 max reward 0.0
# train steps 0 test steps 210 max reward 0.0
# train steps 0 test steps 211 max reward 0.0
# train steps 0 test steps 212 max reward 0.0
# train steps 0 test steps 213 max reward 0.0
# train steps 0 test steps 214 max reward 0.0
# train steps 0 test steps 215 max reward 0.0
# train steps 0 test steps 216 max reward 0.0
# train steps 0 test steps 217 max reward 0.0
# train steps 0 test steps 218 max reward 0.0
# train steps 0 test steps 219 max reward 0.0
# train steps 0 test steps 220 max reward 0.0
# train steps 0 test steps 221 max reward 0.0
# train steps 0 test steps 222 max reward 0.0
# train steps 0 test steps 223 max reward 0.0
# train steps 0 test steps 224 max reward 0.0
# train steps 0 test steps 225 max reward 0.0
# train steps 0 test steps 226 max reward 0.0
# train steps 0 test steps 227 max reward 0.0
# train steps 0 test steps 228 max reward 0.0
# train steps 0 test steps 229 max reward 0.0
# train steps 0 test steps 230 max reward 0.0
# train steps 0 test steps 231 max reward 0.0
# train steps 0 test steps 232 max reward 0.0
# train steps 0 test steps 233 max reward 0.0
# train steps 0 test steps 234 max reward 0.0
# train steps 0 test steps 235 max reward 0.0
# train steps 0 test steps 236 max reward 0.0
# train steps 0 test steps 237 max reward 0.0
# train steps 0 test steps 238 max reward 0.0
# train steps 0 test steps 239 max reward 0.0
# train steps 0 test steps 240 max reward 0.0
# train steps 0 test steps 241 max reward 0.0
# train steps 0 test steps 242 max reward 0.0
# train steps 0 test steps 243 max reward 0.0
# train steps 0 test steps 244 max reward 0.0
# train steps 0 test steps 245 max reward 0.0
# train steps 0 test steps 246 max reward 0.0
# train steps 0 test steps 247 max reward 0.0
# train steps 0 test steps 248 max reward 0.0
# train steps 0 test steps 249 max reward 0.0
# train steps 0 test steps 250 max reward 0.0
# train steps 0 test steps 251 max reward 0.0
# train steps 0 test steps 252 max reward 0.0
# train steps 0 test steps 253 max reward 0.0
# train steps 0 test steps 254 max reward 0.0
# train steps 0 test steps 255 max reward 0.0
# train steps 0 test steps 256 max reward 0.0
# train steps 0 test steps 257 max reward 0.0
# train steps 0 test steps 258 max reward 0.0
# train steps 0 test steps 259 max reward 0.0
# train steps 0 test steps 260 max reward 0.0
# train steps 0 test steps 261 max reward 0.0
# train steps 0 test steps 262 max reward 0.0
# train steps 0 test steps 263 max reward 0.0
# train steps 0 test steps 264 max reward 0.0
# train steps 0 test steps 265 max reward 0.0
# train steps 0 test steps 266 max reward 0.0
# train steps 0 test steps 267 max reward 0.0
# train steps 0 test steps 268 max reward 0.0
# train steps 0 test steps 269 max reward 0.0
# train steps 0 test steps 270 max reward 0.0
# train steps 0 test steps 271 max reward 0.0
# train steps 0 test steps 272 max reward 0.0
# train steps 0 test steps 273 max reward 0.0
# train steps 0 test steps 274 max reward 0.0
# train steps 0 test steps 275 max reward 0.0
# train steps 0 test steps 276 max reward 0.0
# train steps 0 test steps 277 max reward 0.0
# train steps 0 test steps 278 max reward 0.0
# train steps 0 test steps 279 max reward 0.0
# train steps 0 test steps 280 max reward 0.0
# train steps 0 test steps 281 max reward 0.0
# train steps 0 test steps 282 max reward 0.0
# train steps 0 test steps 283 max reward 0.0
# train steps 0 test steps 284 max reward 0.0
# train steps 0 test steps 285 max reward 0.0
# train steps 0 test steps 286 max reward 0.0
# train steps 0 test steps 287 max reward 0.0
# train steps 0 test steps 288 max reward 0.0
# train steps 0 test steps 289 max reward 0.0
# train steps 0 test steps 290 max reward 0.0
# train steps 0 test steps 291 max reward 0.0
# train steps 0 test steps 292 max reward 0.0
# train steps 0 test steps 293 max reward 0.0
# train steps 0 test steps 294 max reward 0.0
# train steps 0 test steps 295 max reward 0.0
# train steps 0 test steps 296 max reward 0.0
# train steps 0 test steps 297 max reward 0.0
# train steps 0 test steps 298 max reward 0.0
# train steps 0 test steps 299 max reward 0.0
# train steps 0 test steps 300 max reward 0.0
# train steps 0 test steps 301 max reward 0.0
# train steps 0 test steps 302 max reward 0.0
# train steps 0 test steps 303 max reward 0.0
# train steps 0 test steps 304 max reward 0.0
# train steps 0 test steps 305 max reward 0.0
# train steps 0 test steps 306 max reward 0.0
# train steps 0 test steps 307 max reward 0.0
# train steps 0 test steps 308 max reward 0.0
# train steps 0 test steps 309 max reward 0.0
# train steps 0 test steps 310 max reward 0.0
# train steps 0 test steps 311 max reward 0.0
# train steps 0 test steps 312 max reward 0.0
# train steps 0 test steps 313 max reward 0.0
# train steps 0 test steps 314 max reward 0.0
# train steps 0 test steps 315 max reward 0.0
# train steps 0 test steps 316 max reward 0.0
# train steps 0 test steps 317 max reward 0.0
# train steps 0 test steps 318 max reward 0.0
# train steps 0 test steps 319 max reward 0.0
# train steps 0 test steps 320 max reward 0.0
# train steps 0 test steps 321 max reward 0.0
# train steps 0 test steps 322 max reward 0.0
# train steps 0 test steps 323 max reward 0.0
# train steps 0 test steps 324 max reward 0.0
# train steps 0 test steps 325 max reward 0.0
# train steps 0 test steps 326 max reward 0.0
# train steps 0 test steps 327 max reward 0.0
# train steps 0 test steps 328 max reward 0.0
# train steps 0 test steps 329 max reward 0.0
# train steps 0 test steps 330 max reward 0.0
# train steps 0 test steps 331 max reward 0.0
# train steps 0 test steps 332 max reward 0.0
# train steps 0 test steps 333 max reward 0.0
# train steps 0 test steps 334 max reward 0.0
# train steps 0 test steps 335 max reward 0.0
# train steps 0 test steps 336 max reward 0.0
# train steps 0 test steps 337 max reward 0.0
# train steps 0 test steps 338 max reward 0.0
# train steps 0 test steps 339 max reward 0.0
# train steps 0 test steps 340 max reward 0.0
# train steps 0 test steps 341 max reward 0.0
# train steps 0 test steps 342 max reward 0.0
# train steps 0 test steps 343 max reward 0.0
# train steps 0 test steps 344 max reward 0.0
# train steps 0 test steps 345 max reward 0.0
# train steps 0 test steps 346 max reward 0.0
# train steps 0 test steps 347 max reward 0.0
# train steps 0 test steps 348 max reward 0.0
# train steps 0 test steps 349 max reward 0.0
# train steps 0 test steps 350 max reward 0.0
# train steps 0 test steps 351 max reward 0.0
# train steps 0 test steps 352 max reward 0.0
# train steps 0 test steps 353 max reward 0.0
# train steps 0 test steps 354 max reward 0.0
# train steps 0 test steps 355 max reward 0.0
# train steps 0 test steps 356 max reward 0.0
# train steps 0 test steps 357 max reward 0.0
# train steps 0 test steps 358 max reward 0.0
# train steps 0 test steps 359 max reward 0.0
# train steps 0 test steps 360 max reward 0.0
# train steps 0 test steps 361 max reward 0.0
# train steps 0 test steps 362 max reward 0.0
# train steps 0 test steps 363 max reward 0.0
# train steps 0 test steps 364 max reward 0.0
# train steps 0 test steps 365 max reward 0.0
# train steps 0 test steps 366 max reward 0.0
# train steps 0 test steps 367 max reward 0.0
# train steps 0 test steps 368 max reward 0.0
# train steps 0 test steps 369 max reward 0.0
# train steps 0 test steps 370 max reward 0.0
# train steps 0 test steps 371 max reward 0.0
# train steps 0 test steps 372 max reward 0.0
# train steps 0 test steps 373 max reward 0.0
# train steps 0 test steps 374 max reward 0.0
# train steps 0 test steps 375 max reward 0.0
# train steps 0 test steps 376 max reward 0.0
# train steps 0 test steps 377 max reward 0.0
# train steps 0 test steps 378 max reward 0.0
# train steps 0 test steps 379 max reward 0.0
# train steps 0 test steps 380 max reward 0.0
# train steps 0 test steps 381 max reward 0.0
# train steps 0 test steps 382 max reward 0.0
# train steps 0 test steps 383 max reward 0.0
# train steps 0 test steps 384 max reward 0.0
# train steps 0 test steps 385 max reward 0.0
# train steps 0 test steps 386 max reward 0.0
# train steps 0 test steps 387 max reward 0.0
# train steps 0 test steps 388 max reward 0.0
# train steps 0 test steps 389 max reward 0.0
# train steps 0 test steps 390 max reward 0.0
# train steps 0 test steps 391 max reward 0.0
# train steps 0 test steps 392 max reward 0.0
# train steps 0 test steps 393 max reward 0.0
# train steps 0 test steps 394 max reward 0.0
# train steps 0 test steps 395 max reward 0.0
# train steps 0 test steps 396 max reward 0.0
# train steps 0 test steps 397 max reward 0.0
# train steps 0 test steps 398 max reward 0.0
# train steps 0 test steps 399 max reward 0.0
# train steps 0 test steps 400 max reward 0.0
# train steps 0 test steps 401 max reward 0.0
# train steps 0 test steps 402 max reward 0.0
# train steps 0 test steps 403 max reward 0.0
# train steps 0 test steps 404 max reward 0.0
# train steps 0 test steps 405 max reward 0.0
# train steps 0 test steps 406 max reward 0.0
# train steps 0 test steps 407 max reward 0.0
# train steps 0 test steps 408 max reward 0.0
# train steps 0 test steps 409 max reward 0.0
# train steps 0 test steps 410 max reward 0.0
# train steps 0 test steps 411 max reward 0.0
# train steps 0 test steps 412 max reward 0.0
# train steps 0 test steps 413 max reward 0.0
# train steps 0 test steps 414 max reward 0.0
# train steps 0 test steps 415 max reward 0.0
# train steps 0 test steps 416 max reward 0.0
# train steps 0 test steps 417 max reward 0.0
# train steps 0 test steps 418 max reward 0.0
# train steps 0 test steps 419 max reward 0.0
# train steps 0 test steps 420 max reward 0.0
# train steps 0 test steps 421 max reward 0.0
# train steps 0 test steps 422 max reward 0.0
# train steps 0 test steps 423 max reward 0.0
# train steps 0 test steps 424 max reward 0.0
# train steps 0 test steps 425 max reward 0.0
# train steps 0 test steps 426 max reward 0.0
# train steps 0 test steps 427 max reward 0.0
# train steps 0 test steps 428 max reward 0.0
# train steps 0 test steps 429 max reward 0.0
# train steps 0 test steps 430 max reward 0.0
# train steps 0 test steps 431 max reward 0.0
# train steps 0 test steps 432 max reward 0.0
# train steps 0 test steps 433 max reward 0.0
# train steps 0 test steps 434 max reward 0.0
# train steps 0 test steps 435 max reward 0.0
# train steps 0 test steps 436 max reward 0.0
# train steps 0 test steps 437 max reward 0.0
# train steps 0 test steps 438 max reward 0.0
# train steps 0 test steps 439 max reward 0.0
# train steps 0 test steps 440 max reward 0.0
# train steps 0 test steps 441 max reward 0.0
# train steps 0 test steps 442 max reward 0.0
# train steps 0 test steps 443 max reward 0.0
# train steps 0 test steps 444 max reward 0.0
# train steps 0 test steps 445 max reward 0.0
# train steps 0 test steps 446 max reward 0.0
# train steps 0 test steps 447 max reward 0.0
# train steps 0 test steps 448 max reward 0.0
# train steps 0 test steps 449 max reward 0.0
# train steps 0 test steps 450 max reward 0.0
# train steps 0 test steps 451 max reward 0.0
# train steps 0 test steps 452 max reward 0.0
# train steps 0 test steps 453 max reward 0.0
# train steps 0 test steps 454 max reward 0.0
# train steps 0 test steps 455 max reward 0.0
# train steps 0 test steps 456 max reward 0.0
# train steps 0 test steps 457 max reward 0.0
# train steps 0 test steps 458 max reward 0.0
# train steps 0 test steps 459 max reward 0.0
# train steps 0 test steps 460 max reward 0.0
# train steps 0 test steps 461 max reward 0.0
# train steps 0 test steps 462 max reward 0.0
# train steps 0 test steps 463 max reward 0.0
# train steps 0 test steps 464 max reward 0.0
# train steps 0 test steps 465 max reward 0.0
# train steps 0 test steps 466 max reward 0.0
# train steps 0 test steps 467 max reward 0.0
# train steps 0 test steps 468 max reward 0.0
# train steps 0 test steps 469 max reward 0.0
# train steps 0 test steps 470 max reward 0.0
# train steps 0 test steps 471 max reward 0.0
# train steps 0 test steps 472 max reward 0.0
# train steps 0 test steps 473 max reward 0.0
# train steps 0 test steps 474 max reward 0.0
# train steps 0 test steps 475 max reward 0.0
# train steps 0 test steps 476 max reward 0.0
# train steps 0 test steps 477 max reward 0.0
# train steps 0 test steps 478 max reward 0.0
# train steps 0 test steps 479 max reward 0.0
# train steps 0 test steps 480 max reward 0.0
# train steps 0 test steps 481 max reward 0.0
# train steps 0 test steps 482 max reward 0.0
# train steps 0 test steps 483 max reward 0.0
# train steps 0 test steps 484 max reward 0.0
# train steps 0 test steps 485 max reward 0.0
# train steps 0 test steps 486 max reward 0.0
# train steps 0 test steps 487 max reward 0.0
# train steps 0 test steps 488 max reward 0.0
# train steps 0 test steps 489 max reward 0.0
# train steps 0 test steps 490 max reward 0.0
# train steps 0 test steps 491 max reward 0.0
# train steps 0 test steps 492 max reward 0.0
# train steps 0 test steps 493 max reward 0.0
# train steps 0 test steps 494 max reward 0.0
# train steps 0 test steps 495 max reward 0.0
# train steps 0 test steps 496 max reward 0.0
# train steps 0 test steps 497 max reward 0.0
# train steps 0 test steps 498 max reward 0.0
# train steps 0 test steps 499 max reward 0.0
# train steps 0 test steps 500 max reward 0.0
# train steps 0 test steps 501 max reward 0.0
# train steps 0 test steps 502 max reward 0.0
# train steps 0 test steps 503 max reward 0.0
# train steps 0 test steps 504 max reward 0.0
# train steps 0 test steps 505 max reward 0.0
# train steps 0 test steps 506 max reward 0.0
# train steps 0 test steps 507 max reward 0.0
# train steps 0 test steps 508 max reward 0.0
# train steps 0 test steps 509 max reward 0.0
# train steps 0 test steps 510 max reward 0.0
# train steps 0 test steps 511 max reward 0.0
# train steps 0 test steps 512 max reward 0.0
# train steps 0 test steps 513 max reward 0.0
# train steps 0 test steps 514 max reward 0.0
# train steps 0 test steps 515 max reward 0.0
# train steps 0 test steps 516 max reward 0.0
# train steps 0 test steps 517 max reward 0.0
# train steps 0 test steps 518 max reward 0.0
# train steps 0 test steps 519 max reward 0.0
# train steps 0 test steps 520 max reward 0.0
# train steps 0 test steps 521 max reward 0.0
# train steps 0 test steps 522 max reward 0.0
# train steps 0 test steps 523 max reward 0.0
# train steps 0 test steps 524 max reward 0.0
# train steps 0 test steps 525 max reward 0.0
# train steps 0 test steps 526 max reward 0.0
# train steps 0 test steps 527 max reward 0.0
# train steps 0 test steps 528 max reward 0.0
# train steps 0 test steps 529 max reward 0.0
# train steps 0 test steps 530 max reward 0.0
# train steps 0 test steps 531 max reward 0.0
# train steps 0 test steps 532 max reward 0.0
# train steps 0 test steps 533 max reward 0.0
# train steps 0 test steps 534 max reward 0.0
# train steps 0 test steps 535 max reward 0.0
# train steps 0 test steps 536 max reward 0.0
# train steps 0 test steps 537 max reward 0.0
# train steps 0 test steps 538 max reward 0.0
# train steps 0 test steps 539 max reward 0.0
# train steps 0 test steps 540 max reward 0.0
# train steps 0 test steps 541 max reward 0.0
# train steps 0 test steps 542 max reward 0.0
# train steps 0 test steps 543 max reward 0.0
# train steps 0 test steps 544 max reward 0.0
# train steps 0 test steps 545 max reward 0.0
# train steps 0 test steps 546 max reward 0.0
# train steps 0 test steps 547 max reward 0.0
# train steps 0 test steps 548 max reward 0.0
# train steps 0 test steps 549 max reward 0.0
# train steps 0 test steps 550 max reward 0.0
# train steps 0 test steps 551 max reward 0.0
# train steps 0 test steps 552 max reward 0.0
# train steps 0 test steps 553 max reward 0.0
# train steps 0 test steps 554 max reward 0.0
# train steps 0 test steps 555 max reward 0.0
# train steps 0 test steps 556 max reward 0.0
# train steps 0 test steps 557 max reward 0.0
# train steps 0 test steps 558 max reward 0.0
# train steps 0 test steps 559 max reward 0.0
# train steps 0 test steps 560 max reward 0.0
# train steps 0 test steps 561 max reward 0.0
# train steps 0 test steps 562 max reward 0.0
# train steps 0 test steps 563 max reward 0.0
# train steps 0 test steps 564 max reward 0.0
# train steps 0 test steps 565 max reward 0.0
# train steps 0 test steps 566 max reward 0.0
# train steps 0 test steps 567 max reward 0.0
# train steps 0 test steps 568 max reward 0.0
# train steps 0 test steps 569 max reward 0.0
# train steps 0 test steps 570 max reward 0.0
# train steps 0 test steps 571 max reward 0.0
# train steps 0 test steps 572 max reward 0.0
# train steps 0 test steps 573 max reward 0.0
# train steps 0 test steps 574 max reward 0.0
# train steps 0 test steps 575 max reward 0.0
# train steps 0 test steps 576 max reward 0.0
# train steps 0 test steps 577 max reward 0.0
# train steps 0 test steps 578 max reward 0.0
# train steps 0 test steps 579 max reward 0.0
# train steps 0 test steps 580 max reward 0.0
# train steps 0 test steps 581 max reward 0.0
# train steps 0 test steps 582 max reward 0.0
# train steps 0 test steps 583 max reward 0.0
# train steps 0 test steps 584 max reward 0.0
# train steps 0 test steps 585 max reward 0.0
# train steps 0 test steps 586 max reward 0.0
# train steps 0 test steps 587 max reward 0.0
# train steps 0 test steps 588 max reward 0.0
# train steps 0 test steps 589 max reward 0.0
# train steps 0 test steps 590 max reward 0.0
# train steps 0 test steps 591 max reward 0.0
# train steps 0 test steps 592 max reward 0.0
# train steps 0 test steps 593 max reward 0.0
# train steps 0 test steps 594 max reward 0.0
# train steps 0 test steps 595 max reward 0.0
# train steps 0 test steps 596 max reward 0.0
# train steps 0 test steps 597 max reward 0.0
# train steps 0 test steps 598 max reward 0.0
# train steps 0 test steps 599 max reward 0.0
# train steps 0 test steps 600 max reward 0.0
# train steps 0 test steps 601 max reward 0.0
# train steps 0 test steps 602 max reward 0.0
# train steps 0 test steps 603 max reward 0.0
# train steps 0 test steps 604 max reward 0.0
# train steps 0 test steps 605 max reward 0.0
# train steps 0 test steps 606 max reward 0.0
# train steps 0 test steps 607 max reward 0.0
# train steps 0 test steps 608 max reward 0.0
# train steps 0 test steps 609 max reward 0.0
# train steps 0 test steps 610 max reward 0.0
# train steps 0 test steps 611 max reward 0.0
# train steps 0 test steps 612 max reward 0.0
# train steps 0 test steps 613 max reward 0.0
# train steps 0 test steps 614 max reward 0.0
# train steps 0 test steps 615 max reward 0.0
# train steps 0 test steps 616 max reward 0.0
# train steps 0 test steps 617 max reward 0.0
# train steps 0 test steps 618 max reward 0.0
# train steps 0 test steps 619 max reward 0.0
# train steps 0 test steps 620 max reward 0.0
# train steps 0 test steps 621 max reward 0.0
# train steps 0 test steps 622 max reward 0.0
# train steps 0 test steps 623 max reward 0.0
# train steps 0 test steps 624 max reward 0.0
# train steps 0 test steps 625 max reward 0.0
# train steps 0 test steps 626 max reward 0.0
# train steps 0 test steps 627 max reward 0.0
# train steps 0 test steps 628 max reward 0.0
# train steps 0 test steps 629 max reward 0.0
# train steps 0 test steps 630 max reward 0.0
# train steps 0 test steps 631 max reward 0.0
# train steps 0 test steps 632 max reward 0.0
# train steps 0 test steps 633 max reward 0.0
# train steps 0 test steps 634 max reward 0.0
# train steps 0 test steps 635 max reward 0.0
# train steps 0 test steps 636 max reward 0.0
# train steps 0 test steps 637 max reward 0.0
# train steps 0 test steps 638 max reward 0.0
# train steps 0 test steps 639 max reward 0.0
# train steps 0 test steps 640 max reward 0.0
# train steps 0 test steps 641 max reward 0.0
# train steps 0 test steps 642 max reward 0.0
# train steps 0 test steps 643 max reward 0.0
# train steps 0 test steps 644 max reward 0.0
# train steps 0 test steps 645 max reward 0.0
# train steps 0 test steps 646 max reward 0.0
# train steps 0 test steps 647 max reward 0.0
# train steps 0 test steps 648 max reward 0.0
# train steps 0 test steps 649 max reward 0.0
# train steps 0 test steps 650 max reward 0.0
# train steps 0 test steps 651 max reward 0.0
# train steps 0 test steps 652 max reward 0.0
# train steps 0 test steps 653 max reward 0.0
# train steps 0 test steps 654 max reward 0.0
# train steps 0 test steps 655 max reward 0.0
# train steps 0 test steps 656 max reward 0.0
# train steps 0 test steps 657 max reward 0.0
# train steps 0 test steps 658 max reward 0.0
# train steps 0 test steps 659 max reward 0.0
# train steps 0 test steps 660 max reward 0.0
# train steps 0 test steps 661 max reward 0.0
# train steps 0 test steps 662 max reward 0.0
# train steps 0 test steps 663 max reward 0.0
# train steps 0 test steps 664 max reward 0.0
# train steps 0 test steps 665 max reward 0.0
# train steps 0 test steps 666 max reward 0.0
# train steps 0 test steps 667 max reward 0.0
# train steps 0 test steps 668 max reward 0.0
# train steps 0 test steps 669 max reward 0.0
# train steps 0 test steps 670 max reward 0.0
# train steps 0 test steps 671 max reward 0.0
# train steps 0 test steps 672 max reward 0.0
# train steps 0 test steps 673 max reward 0.0
# train steps 0 test steps 674 max reward 0.0
# train steps 0 test steps 675 max reward 0.0
# train steps 0 test steps 676 max reward 0.0
# train steps 0 test steps 677 max reward 0.0
# train steps 0 test steps 678 max reward 0.0
# train steps 0 test steps 679 max reward 0.0
# train steps 0 test steps 680 max reward 0.0
# train steps 0 test steps 681 max reward 0.0
# train steps 0 test steps 682 max reward 0.0
# train steps 0 test steps 683 max reward 0.0
# train steps 0 test steps 684 max reward 0.0
# train steps 0 test steps 685 max reward 0.0
# train steps 0 test steps 686 max reward 0.0
# train steps 0 test steps 687 max reward 0.0
# train steps 0 test steps 688 max reward 0.0
# train steps 0 test steps 689 max reward 0.0
# train steps 0 test steps 690 max reward 0.0
# train steps 0 test steps 691 max reward 0.0
# train steps 0 test steps 692 max reward 0.0
# train steps 0 test steps 693 max reward 0.0
# train steps 0 test steps 694 max reward 0.0
# train steps 0 test steps 695 max reward 0.0
# train steps 0 test steps 696 max reward 0.0
# train steps 0 test steps 697 max reward 0.0
# train steps 0 test steps 698 max reward 0.0
# train steps 0 test steps 699 max reward 0.0
# train steps 0 test steps 700 max reward 0.0
# train steps 0 test steps 701 max reward 0.0
# train steps 0 test steps 702 max reward 0.0
# train steps 0 test steps 703 max reward 0.0
# train steps 0 test steps 704 max reward 0.0
# train steps 0 test steps 705 max reward 0.0
# train steps 0 test steps 706 max reward 0.0
# train steps 0 test steps 707 max reward 0.0
# train steps 0 test steps 708 max reward 0.0
# train steps 0 test steps 709 max reward 0.0
# train steps 0 test steps 710 max reward 0.0
# train steps 0 test steps 711 max reward 0.0
# train steps 0 test steps 712 max reward 0.0
# train steps 0 test steps 713 max reward 0.0
# train steps 0 test steps 714 max reward 0.0
# train steps 0 test steps 715 max reward 0.0
# train steps 0 test steps 716 max reward 0.0
# train steps 0 test steps 717 max reward 0.0
# train steps 0 test steps 718 max reward 0.0
# train steps 0 test steps 719 max reward 0.0
# train steps 0 test steps 720 max reward 0.0
# train steps 0 test steps 721 max reward 0.0
# train steps 0 test steps 722 max reward 0.0
# train steps 0 test steps 723 max reward 0.0
# train steps 0 test steps 724 max reward 0.0
# train steps 0 test steps 725 max reward 0.0
# train steps 0 test steps 726 max reward 0.0
# train steps 0 test steps 727 max reward 0.0
# train steps 0 test steps 728 max reward 0.0
# train steps 0 test steps 729 max reward 0.0
# train steps 0 test steps 730 max reward 0.0
# train steps 0 test steps 731 max reward 0.0
# train steps 0 test steps 732 max reward 0.0
# train steps 0 test steps 733 max reward 0.0
# train steps 0 test steps 734 max reward 0.0
# train steps 0 test steps 735 max reward 0.0
# train steps 0 test steps 736 max reward 0.0
# train steps 0 test steps 737 max reward 0.0
# train steps 0 test steps 738 max reward 0.0
# train steps 0 test steps 739 max reward 0.0
# train steps 0 test steps 740 max reward 0.0
# train steps 0 test steps 741 max reward 0.0
# train steps 0 test steps 742 max reward 0.0
# train steps 0 test steps 743 max reward 0.0
# train steps 0 test steps 744 max reward 0.0
# train steps 0 test steps 745 max reward 0.0
# train steps 0 test steps 746 max reward 0.0
# train steps 0 test steps 747 max reward 0.0
# train steps 0 test steps 748 max reward 0.0
# train steps 0 test steps 749 max reward 0.0
# train steps 0 test steps 750 max reward 0.0
# train steps 0 test steps 751 max reward 0.0
# train steps 0 test steps 752 max reward 0.0
# train steps 0 test steps 753 max reward 0.0
# train steps 0 test steps 754 max reward 0.0
# train steps 0 test steps 755 max reward 0.0
# train steps 0 test steps 756 max reward 0.0
# train steps 0 test steps 757 max reward 0.0
# train steps 0 test steps 758 max reward 0.0
# train steps 0 test steps 759 max reward 0.0
# train steps 0 test steps 760 max reward 0.0
# train steps 0 test steps 761 max reward 0.0
# train steps 0 test steps 762 max reward 0.0
# train steps 0 test steps 763 max reward 0.0
# train steps 0 test steps 764 max reward 0.0
# train steps 0 test steps 765 max reward 0.0
# train steps 0 test steps 766 max reward 0.0
# train steps 0 test steps 767 max reward 0.0
# train steps 0 test steps 768 max reward 0.0
# train steps 0 test steps 769 max reward 0.0
# train steps 0 test steps 770 max reward 0.0
# train steps 0 test steps 771 max reward 0.0
# train steps 0 test steps 772 max reward 0.0
# train steps 0 test steps 773 max reward 0.0
# train steps 0 test steps 774 max reward 0.0
# train steps 0 test steps 775 max reward 0.0
# train steps 0 test steps 776 max reward 0.0
# train steps 0 test steps 777 max reward 0.0
# train steps 0 test steps 778 max reward 0.0
# train steps 0 test steps 779 max reward 0.0
# train steps 0 test steps 780 max reward 0.0
# train steps 0 test steps 781 max reward 0.0
# train steps 0 test steps 782 max reward 0.0
# train steps 0 test steps 783 max reward 0.0
# train steps 0 test steps 784 max reward 0.0
# train steps 0 test steps 785 max reward 0.0
# train steps 0 test steps 786 max reward 0.0
# train steps 0 test steps 787 max reward 0.0
# train steps 0 test steps 788 max reward 0.0
# train steps 0 test steps 789 max reward 0.0
# train steps 0 test steps 790 max reward 0.0
# train steps 0 test steps 791 max reward 0.0
# train steps 0 test steps 792 max reward 1.0
# train steps 0 test steps 793 max reward 1.0
# train steps 0 test steps 794 max reward 1.0
# train steps 0 test steps 795 max reward 1.0
# train steps 0 test steps 796 max reward 1.0
# train steps 0 test steps 797 max reward 1.0
# train steps 0 test steps 798 max reward 1.0
# train steps 0 test steps 799 max reward 1.0
# train steps 0 test steps 800 max reward 1.0
# train steps 0 test steps 801 max reward 1.0
# train steps 0 test steps 802 max reward 1.0
# train steps 0 test steps 803 max reward 1.0
# train steps 0 test steps 804 max reward 1.0
# train steps 0 test steps 805 max reward 1.0
# train steps 0 test steps 806 max reward 1.0
# train steps 0 test steps 807 max reward 1.0
# train steps 0 test steps 808 max reward 1.0
# train steps 0 test steps 809 max reward 1.0
# train steps 0 test steps 810 max reward 1.0
# train steps 0 test steps 811 max reward 1.0
# train steps 0 test steps 812 max reward 1.0
# train steps 0 test steps 813 max reward 1.0
# train steps 0 test steps 814 max reward 1.0
# train steps 0 test steps 815 max reward 1.0
# train steps 0 test steps 816 max reward 1.0
# train steps 0 test steps 817 max reward 1.0
# train steps 0 test steps 818 max reward 1.0
# train steps 0 test steps 819 max reward 1.0
# train steps 0 test steps 820 max reward 1.0
# train steps 0 test steps 821 max reward 1.0
# train steps 0 test steps 822 max reward 1.0
# train steps 0 test steps 823 max reward 1.0
# train steps 0 test steps 824 max reward 1.0
# train steps 0 test steps 825 max reward 1.0
# train steps 0 test steps 826 max reward 1.0
# train steps 0 test steps 827 max reward 1.0
# train steps 0 test steps 828 max reward 1.0
# train steps 0 test steps 829 max reward 1.0
# train steps 0 test steps 830 max reward 1.0
# train steps 0 test steps 831 max reward 1.0
# train steps 0 test steps 832 max reward 1.0
# train steps 0 test steps 833 max reward 1.0
# train steps 0 test steps 834 max reward 1.0
# train steps 0 test steps 835 max reward 1.0
# train steps 0 test steps 836 max reward 1.0
# train steps 0 test steps 837 max reward 1.0
# train steps 0 test steps 838 max reward 1.0
# train steps 0 test steps 839 max reward 1.0
# train steps 0 test steps 840 max reward 1.0
# train steps 0 test steps 841 max reward 1.0
# train steps 0 test steps 842 max reward 1.0
# train steps 0 test steps 843 max reward 1.0
# train steps 0 test steps 844 max reward 1.0
# train steps 0 test steps 845 max reward 1.0
# train steps 0 test steps 846 max reward 1.0
# train steps 0 test steps 847 max reward 1.0
# train steps 0 test steps 848 max reward 1.0
# train steps 0 test steps 849 max reward 1.0
# train steps 0 test steps 850 max reward 1.0
# train steps 0 test steps 851 max reward 1.0
# train steps 0 test steps 852 max reward 1.0
# train steps 0 test steps 853 max reward 1.0
# train steps 0 test steps 854 max reward 1.0
# train steps 0 test steps 855 max reward 1.0
# train steps 0 test steps 856 max reward 1.0
# train steps 0 test steps 857 max reward 1.0
# train steps 0 test steps 858 max reward 1.0
# train steps 0 test steps 859 max reward 1.0
# train steps 0 test steps 860 max reward 1.0
# train steps 0 test steps 861 max reward 1.0
# train steps 0 test steps 862 max reward 1.0
# train steps 0 test steps 863 max reward 1.0
# train steps 0 test steps 864 max reward 1.0
# train steps 0 test steps 865 max reward 1.0
# train steps 0 test steps 866 max reward 1.0
# train steps 0 test steps 867 max reward 1.0
# train steps 0 test steps 868 max reward 1.0
# train steps 0 test steps 869 max reward 1.0
# train steps 0 test steps 870 max reward 1.0
# train steps 0 test steps 871 max reward 1.0
# train steps 0 test steps 872 max reward 1.0
# train steps 0 test steps 873 max reward 1.0
# train steps 0 test steps 874 max reward 1.0
# train steps 0 test steps 875 max reward 1.0
# train steps 0 test steps 876 max reward 1.0
# train steps 0 test steps 877 max reward 1.0
# train steps 0 test steps 878 max reward 1.0
# train steps 0 test steps 879 max reward 1.0
# train steps 0 test steps 880 max reward 1.0
# train steps 0 test steps 881 max reward 1.0
# train steps 0 test steps 882 max reward 1.0
# train steps 0 test steps 883 max reward 1.0
# train steps 0 test steps 884 max reward 1.0
# train steps 0 test steps 885 max reward 1.0
# train steps 0 test steps 886 max reward 1.0
# train steps 0 test steps 887 max reward 1.0
# train steps 0 test steps 888 max reward 1.0
# train steps 0 test steps 889 max reward 1.0
# train steps 0 test steps 890 max reward 1.0
# train steps 0 test steps 891 max reward 1.0
# train steps 0 test steps 892 max reward 1.0
# train steps 0 test steps 893 max reward 1.0
# train steps 0 test steps 894 max reward 1.0
# train steps 0 test steps 895 max reward 1.0
# train steps 0 test steps 896 max reward 1.0
# train steps 0 test steps 897 max reward 1.0
# train steps 0 test steps 898 max reward 1.0
# train steps 0 test steps 899 max reward 1.0
# train steps 0 test steps 900 max reward 1.0
# train steps 0 test steps 901 max reward 1.0
# train steps 0 test steps 902 max reward 1.0
# train steps 0 test steps 903 max reward 1.0
# train steps 0 test steps 904 max reward 1.0
# train steps 0 test steps 905 max reward 1.0
# train steps 0 test steps 906 max reward 1.0
# train steps 0 test steps 907 max reward 1.0
# train steps 0 test steps 908 max reward 1.0
# train steps 0 test steps 909 max reward 1.0
# train steps 0 test steps 910 max reward 1.0
# train steps 0 test steps 911 max reward 1.0
# train steps 0 test steps 912 max reward 1.0
# train steps 0 test steps 913 max reward 1.0
# train steps 0 test steps 914 max reward 1.0
# train steps 0 test steps 915 max reward 1.0
# train steps 0 test steps 916 max reward 1.0
# train steps 0 test steps 917 max reward 1.0
# train steps 0 test steps 918 max reward 1.0
# train steps 0 test steps 919 max reward 1.0
# train steps 0 test steps 920 max reward 1.0
# train steps 0 test steps 921 max reward 1.0
# train steps 0 test steps 922 max reward 1.0
# train steps 0 test steps 923 max reward 1.0
# train steps 0 test steps 924 max reward 1.0
# train steps 0 test steps 925 max reward 1.0
# train steps 0 test steps 926 max reward 1.0
# train steps 0 test steps 927 max reward 1.0
# train steps 0 test steps 928 max reward 1.0
# train steps 0 test steps 929 max reward 1.0
# train steps 0 test steps 930 max reward 1.0
# train steps 0 test steps 931 max reward 1.0
# train steps 0 test steps 932 max reward 1.0
# train steps 0 test steps 933 max reward 1.0
# train steps 0 test steps 934 max reward 1.0
# train steps 0 test steps 935 max reward 1.0
# train steps 0 test steps 936 max reward 1.0
# train steps 0 test steps 937 max reward 1.0
# train steps 0 test steps 938 max reward 1.0
# train steps 0 test steps 939 max reward 1.0
# train steps 0 test steps 940 max reward 1.0
# train steps 0 test steps 941 max reward 1.0
# train steps 0 test steps 942 max reward 1.0
# train steps 0 test steps 943 max reward 1.0
# train steps 0 test steps 944 max reward 1.0
# train steps 0 test steps 945 max reward 1.0
# train steps 0 test steps 946 max reward 1.0
# train steps 0 test steps 947 max reward 1.0
# train steps 0 test steps 948 max reward 1.0
# train steps 0 test steps 949 max reward 1.0
# train steps 0 test steps 950 max reward 1.0
# train steps 0 test steps 951 max reward 1.0
# train steps 0 test steps 952 max reward 1.0
# train steps 0 test steps 953 max reward 1.0
# train steps 0 test steps 954 max reward 1.0
# train steps 0 test steps 955 max reward 1.0
# train steps 0 test steps 956 max reward 1.0
# train steps 0 test steps 957 max reward 1.0
# train steps 0 test steps 958 max reward 1.0
# train steps 0 test steps 959 max reward 1.0
# train steps 0 test steps 960 max reward 1.0
# train steps 0 test steps 961 max reward 1.0
# train steps 0 test steps 962 max reward 1.0
# train steps 0 test steps 963 max reward 1.0
# train steps 0 test steps 964 max reward 1.0
# train steps 0 test steps 965 max reward 1.0
# train steps 0 test steps 966 max reward 1.0
# train steps 0 test steps 967 max reward 1.0
# train steps 0 test steps 968 max reward 1.0
# train steps 0 test steps 969 max reward 1.0
# train steps 0 test steps 970 max reward 1.0
# train steps 0 test steps 971 max reward 1.0
# train steps 0 test steps 972 max reward 1.0
# train steps 0 test steps 973 max reward 1.0
# train steps 0 test steps 974 max reward 1.0
# train steps 0 test steps 975 max reward 1.0
# train steps 0 test steps 976 max reward 1.0
# train steps 0 test steps 977 max reward 1.0
# train steps 0 test steps 978 max reward 1.0
# train steps 0 test steps 979 max reward 1.0
# train steps 0 test steps 980 max reward 1.0
# train steps 0 test steps 981 max reward 1.0
# train steps 0 test steps 982 max reward 1.0
# train steps 0 test steps 983 max reward 1.0
# train steps 0 test steps 984 max reward 1.0
# train steps 0 test steps 985 max reward 1.0
# train steps 0 test steps 986 max reward 1.0
# train steps 0 test steps 987 max reward 1.0
# train steps 0 test steps 988 max reward 1.0
# train steps 0 test steps 989 max reward 1.0
# train steps 0 test steps 990 max reward 1.0
# train steps 0 test steps 991 max reward 1.0
# train steps 0 test steps 992 max reward 1.0
# train steps 0 test steps 993 max reward 1.0
# train steps 0 test steps 994 max reward 1.0
# train steps 0 test steps 995 max reward 1.0
# train steps 0 test steps 996 max reward 1.0
# train steps 0 test steps 997 max reward 1.0
# train steps 0 test steps 998 max reward 1.0
# train steps 0 test steps 999 max reward 1.0
# train steps 0 test steps 1000 max reward 1.0
# train steps 0 test steps 1001 max reward 1.0
# train steps 0 test steps 1002 max reward 1.0
# train steps 0 test steps 1003 max reward 1.0
# train steps 0 test steps 1004 max reward 1.0
# train steps 0 test steps 1005 max reward 1.0
# train steps 0 test steps 1006 max reward 1.0
# train steps 0 test steps 1007 max reward 1.0
# train steps 0 test steps 1008 max reward 1.0
# train steps 0 test steps 1009 max reward 1.0
# train steps 0 test steps 1010 max reward 1.0
# train steps 0 test steps 1011 max reward 1.0
# train steps 0 test steps 1012 max reward 1.0
# train steps 0 test steps 1013 max reward 1.0
# train steps 0 test steps 1014 max reward 1.0
# train steps 0 test steps 1015 max reward 1.0
# train steps 0 test steps 1016 max reward 1.0
# train steps 0 test steps 1017 max reward 1.0
# train steps 0 test steps 1018 max reward 1.0
# train steps 0 test steps 1019 max reward 1.0
# train steps 0 test steps 1020 max reward 1.0
# train steps 0 test steps 1021 max reward 1.0
# train steps 0 test steps 1022 max reward 1.0
# train steps 0 test steps 1023 max reward 1.0
# train steps 0 test steps 1024 max reward 1.0
# train steps 0 test steps 1025 max reward 1.0
# train steps 0 test steps 1026 max reward 1.0
# train steps 0 test steps 1027 max reward 1.0
# train steps 0 test steps 1028 max reward 1.0
# train steps 0 test steps 1029 max reward 1.0
# train steps 0 test steps 1030 max reward 1.0
# train steps 0 test steps 1031 max reward 1.0
# train steps 0 test steps 1032 max reward 1.0
# train steps 0 test steps 1033 max reward 1.0
# train steps 0 test steps 1034 max reward 1.0
# train steps 0 test steps 1035 max reward 1.0
# train steps 0 test steps 1036 max reward 1.0
# train steps 0 test steps 1037 max reward 1.0
# train steps 0 test steps 1038 max reward 1.0
# train steps 0 test steps 1039 max reward 1.0
# train steps 0 test steps 1040 max reward 1.0
# train steps 0 test steps 1041 max reward 1.0
# train steps 0 test steps 1042 max reward 1.0
# train steps 0 test steps 1043 max reward 1.0
# train steps 0 test steps 1044 max reward 1.0
# train steps 0 test steps 1045 max reward 1.0
# train steps 0 test steps 1046 max reward 1.0
# train steps 0 test steps 1047 max reward 1.0
# train steps 0 test steps 1048 max reward 1.0
# train steps 0 test steps 1049 max reward 1.0
# train steps 0 test steps 1050 max reward 1.0
# train steps 0 test steps 1051 max reward 1.0
# train steps 0 test steps 1052 max reward 1.0
# train steps 0 test steps 1053 max reward 1.0
# train steps 0 test steps 1054 max reward 1.0
# train steps 0 test steps 1055 max reward 1.0
# train steps 0 test steps 1056 max reward 1.0
# train steps 0 test steps 1057 max reward 1.0
# train steps 0 test steps 1058 max reward 1.0
# train steps 0 test steps 1059 max reward 1.0
# train steps 0 test steps 1060 max reward 1.0
# train steps 0 test steps 1061 max reward 1.0
# train steps 0 test steps 1062 max reward 1.0
# train steps 0 test steps 1063 max reward 1.0
# train steps 0 test steps 1064 max reward 1.0
# train steps 0 test steps 1065 max reward 1.0
# train steps 0 test steps 1066 max reward 1.0
# train steps 0 test steps 1067 max reward 1.0
# train steps 0 test steps 1068 max reward 1.0
# train steps 0 test steps 1069 max reward 1.0
# train steps 0 test steps 1070 max reward 1.0
# train steps 0 test steps 1071 max reward 1.0
# train steps 0 test steps 1072 max reward 1.0
# train steps 0 test steps 1073 max reward 1.0
# train steps 0 test steps 1074 max reward 1.0
# train steps 0 test steps 1075 max reward 1.0
# train steps 0 test steps 1076 max reward 1.0
# train steps 0 test steps 1077 max reward 1.0
# train steps 0 test steps 1078 max reward 1.0
# train steps 0 test steps 1079 max reward 1.0
# train steps 0 test steps 1080 max reward 1.0
# train steps 0 test steps 1081 max reward 1.0
# train steps 0 test steps 1082 max reward 1.0
# train steps 0 test steps 1083 max reward 1.0
# train steps 0 test steps 1084 max reward 1.0
# train steps 0 test steps 1085 max reward 1.0
# train steps 0 test steps 1086 max reward 1.0
# ...
# train steps 0 test steps 3368 max reward 2.0
# train steps 0 test steps 3369 max reward 2.0
# train steps 0 test steps 3370 max reward 2.0
# train steps 0 test steps 3371 max reward 2.0
# train steps 0 test steps 3372 max reward 2.0
# train steps 0 test steps 3373 max reward 2.0
# train steps 0 test steps 3374 max reward 2.0
# train steps 0 test steps 3375 max reward 2.0
# train steps 0 test steps 3376 max reward 2.0
# train steps 0 test steps 3377 max reward 2.0
# train steps 0 test steps 3378 max reward 2.0
# train steps 0 test steps 3379 max reward 2.0
# train steps 0 test steps 3380 max reward 2.0
# train steps 0 test steps 3381 max reward 2.0
# train steps 0 test steps 3382 max reward 2.0
# train steps 0 test steps 3383 max reward 2.0
# train steps 0 test steps 3384 max reward 2.0
# train steps 0 test steps 3385 max reward 2.0
# train steps 0 test steps 3386 max reward 2.0
# train steps 0 test steps 3387 max reward 2.0
# train steps 0 test steps 3388 max reward 2.0
# train steps 0 test steps 3389 max reward 2.0
# train steps 0 test steps 3390 max reward 2.0
# train steps 0 test steps 3391 max reward 2.0
# train steps 0 test steps 3392 max reward 2.0
# train steps 0 test steps 3393 max reward 2.0
# train steps 0 test steps 3394 max reward 2.0
# train steps 0 test steps 3395 max reward 2.0
# train steps 0 test steps 3396 max reward 2.0
# train steps 0 test steps 3397 max reward 2.0
# train steps 0 test steps 3398 max reward 2.0
# train steps 0 test steps 3399 max reward 2.0
# train steps 0 test steps 3400 max reward 2.0
# train steps 0 test steps 3401 max reward 2.0
# train steps 0 test steps 3402 max reward 2.0
# train steps 0 test steps 3403 max reward 2.0
# train steps 0 test steps 3404 max reward 2.0
# train steps 0 test steps 3405 max reward 2.0
# train steps 0 test steps 3406 max reward 2.0
# train steps 0 test steps 3407 max reward 2.0
# train steps 0 test steps 3408 max reward 2.0
# train steps 0 test steps 3409 max reward 2.0
# train steps 0 test steps 3410 max reward 2.0
# train steps 0 test steps 3411 max reward 2.0
# train steps 0 test steps 3412 max reward 2.0
# train steps 0 test steps 3413 max reward 2.0
# train steps 0 test steps 3414 max reward 2.0
# train steps 0 test steps 3415 max reward 2.0
# train steps 0 test steps 3416 max reward 2.0
# train steps 0 test steps 3417 max reward 2.0
# train steps 0 test steps 3418 max reward 2.0
# train steps 0 test steps 3419 max reward 2.0
# train steps 0 test steps 3420 max reward 2.0
# train steps 0 test steps 3421 max reward 2.0
# train steps 0 test steps 3422 max reward 2.0
# train steps 0 test steps 3423 max reward 2.0
# train steps 0 test steps 3424 max reward 2.0
# train steps 0 test steps 3425 max reward 2.0
# train steps 0 test steps 3426 max reward 2.0
# train steps 0 test steps 3427 max reward 2.0
# train steps 0 test steps 3428 max reward 2.0
# train steps 0 test steps 3429 max reward 2.0
# train steps 0 test steps 3430 max reward 2.0
# train steps 0 test steps 3431 max reward 2.0
# train steps 0 test steps 3432 max reward 2.0
# train steps 0 test steps 3433 max reward 2.0
# train steps 0 test steps 3434 max reward 2.0
# train steps 0 test steps 3435 max reward 2.0
# train steps 0 test steps 3436 max reward 2.0
# train steps 0 test steps 3437 max reward 2.0
# train steps 0 test steps 3438 max reward 2.0
# train steps 0 test steps 3439 max reward 2.0
# train steps 0 test steps 3440 max reward 2.0
# train steps 0 test steps 3441 max reward 2.0
# train steps 0 test steps 3442 max reward 2.0
# train steps 0 test steps 3443 max reward 2.0
# train steps 0 test steps 3444 max reward 2.0
# train steps 0 test steps 3445 max reward 2.0
# train steps 0 test steps 3446 max reward 2.0
# train steps 0 test steps 3447 max reward 2.0
# train steps 0 test steps 3448 max reward 2.0
# train steps 0 test steps 3449 max reward 2.0
# train steps 0 test steps 3450 max reward 2.0
# train steps 0 test steps 3451 max reward 2.0
# train steps 0 test steps 3452 max reward 2.0
# train steps 0 test steps 3453 max reward 2.0
# train steps 0 test steps 3454 max reward 2.0
# train steps 0 test steps 3455 max reward 2.0
# train steps 0 test steps 3456 max reward 2.0
# train steps 0 test steps 3457 max reward 2.0
# train steps 0 test steps 3458 max reward 2.0
# train steps 0 test steps 3459 max reward 2.0
# train steps 0 test steps 3460 max reward 2.0
# train steps 0 test steps 3461 max reward 2.0
# train steps 0 test steps 3462 max reward 2.0
# train steps 0 test steps 3463 max reward 2.0
# train steps 0 test steps 3464 max reward 2.0
# train steps 0 test steps 3465 max reward 2.0
# train steps 0 test steps 3466 max reward 2.0
# train steps 0 test steps 3467 max reward 2.0
# train steps 0 test steps 3468 max reward 2.0
# train steps 0 test steps 3469 max reward 2.0
# train steps 0 test steps 3470 max reward 2.0
# train steps 0 test steps 3471 max reward 2.0
# train steps 0 test steps 3472 max reward 2.0
# train steps 0 test steps 3473 max reward 2.0
# train steps 0 test steps 3474 max reward 2.0
# train steps 0 test steps 3475 max reward 2.0
# train steps 0 test steps 3476 max reward 2.0
# train steps 0 test steps 3477 max reward 2.0
# train steps 0 test steps 3478 max reward 2.0
# train steps 0 test steps 3479 max reward 2.0
# train steps 0 test steps 3480 max reward 2.0
# train steps 0 test steps 3481 max reward 2.0
# train steps 0 test steps 3482 max reward 2.0
# train steps 0 test steps 3483 max reward 2.0
# train steps 0 test steps 3484 max reward 2.0
# train steps 0 test steps 3485 max reward 2.0
# train steps 0 test steps 3486 max reward 2.0
# train steps 0 test steps 3487 max reward 2.0
# train steps 0 test steps 3488 max reward 2.0
# train steps 0 test steps 3489 max reward 2.0
# train steps 0 test steps 3490 max reward 2.0
# train steps 0 test steps 3491 max reward 2.0
# train steps 0 test steps 3492 max reward 2.0
# train steps 0 test steps 3493 max reward 2.0
# train steps 0 test steps 3494 max reward 2.0
# train steps 0 test steps 3495 max reward 2.0
# train steps 0 test steps 3496 max reward 2.0
# train steps 0 test steps 3497 max reward 2.0
# train steps 0 test steps 3498 max reward 2.0
# train steps 0 test steps 3499 max reward 2.0
# train steps 0 test steps 3500 max reward 2.0
# train steps 0 test steps 3501 max reward 2.0
# train steps 0 test steps 3502 max reward 2.0
# train steps 0 test steps 3503 max reward 2.0
# train steps 0 test steps 3504 max reward 2.0
# train steps 0 test steps 3505 max reward 2.0
# train steps 0 test steps 3506 max reward 2.0
# train steps 0 test steps 3507 max reward 2.0
# train steps 0 test steps 3508 max reward 2.0
# train steps 0 test steps 3509 max reward 2.0
# train steps 0 test steps 3510 max reward 2.0
# train steps 0 test steps 3511 max reward 2.0
# train steps 0 test steps 3512 max reward 2.0
# train steps 0 test steps 3513 max reward 2.0
# train steps 0 test steps 3514 max reward 2.0
# train steps 0 test steps 3515 max reward 2.0
# train steps 0 test steps 3516 max reward 2.0
# train steps 0 test steps 3517 max reward 2.0
# train steps 0 test steps 3518 max reward 2.0
# train steps 0 test steps 3519 max reward 2.0
# train steps 0 test steps 3520 max reward 2.0
# train steps 0 test steps 3521 max reward 2.0
# train steps 0 test steps 3522 max reward 2.0
# train steps 0 test steps 3523 max reward 2.0
# train steps 0 test steps 3524 max reward 2.0
# train steps 0 test steps 3525 max reward 2.0
# train steps 0 test steps 3526 max reward 2.0
# train steps 0 test steps 3527 max reward 2.0
# train steps 0 test steps 3528 max reward 2.0
# train steps 0 test steps 3529 max reward 2.0
# train steps 0 test steps 3530 max reward 2.0
# train steps 0 test steps 3531 max reward 2.0
# train steps 0 test steps 3532 max reward 2.0
# train steps 0 test steps 3533 max reward 2.0
# train steps 0 test steps 3534 max reward 2.0
# train steps 0 test steps 3535 max reward 2.0
# train steps 0 test steps 3536 max reward 2.0
# train steps 0 test steps 3537 max reward 2.0
# train steps 0 test steps 3538 max reward 2.0
# train steps 0 test steps 3539 max reward 2.0
# train steps 0 test steps 3540 max reward 2.0
# train steps 0 test steps 3541 max reward 2.0
# train steps 0 test steps 3542 max reward 2.0
# train steps 0 test steps 3543 max reward 2.0
# train steps 0 test steps 3544 max reward 2.0
# train steps 0 test steps 3545 max reward 2.0
# train steps 0 test steps 3546 max reward 2.0
# train steps 0 test steps 3547 max reward 2.0
# train steps 0 test steps 3548 max reward 2.0
# train steps 0 test steps 3549 max reward 2.0
# train steps 0 test steps 3550 max reward 2.0
# train steps 0 test steps 3551 max reward 2.0
# train steps 0 test steps 3552 max reward 2.0
# train steps 0 test steps 3553 max reward 2.0
# train steps 0 test steps 3554 max reward 2.0
# train steps 0 test steps 3555 max reward 2.0
# train steps 0 test steps 3556 max reward 2.0
# train steps 0 test steps 3557 max reward 2.0
# train steps 0 test steps 3558 max reward 2.0
# train steps 0 test steps 3559 max reward 2.0
# train steps 0 test steps 3560 max reward 2.0
# train steps 0 test steps 3561 max reward 2.0
# train steps 0 test steps 3562 max reward 2.0
# train steps 0 test steps 3563 max reward 2.0
# train steps 0 test steps 3564 max reward 2.0
# train steps 0 test steps 3565 max reward 2.0
# train steps 0 test steps 3566 max reward 2.0
# train steps 0 test steps 3567 max reward 2.0
#
# Program interrupted. (Use 'cont' to resume).
# > /home/cbekar/miniconda3/envs/blg604ehw2/lib/python3.7/site-packages/jupyter_client/session.py(132)new_id()
# -> return u'-'.join(b2a_hex(x).decode('ascii') for x in (
# (Pdb) exit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-6-c81d02ddcb9c> in <module>
#      30                      args=(breakout_args, global_agent, breakout_env, breakout_agent, lock, logger))
#      31 # train_worker(breakout_args, global_agent, sharedopt, breakout_env, breakout_agent, 0, N_PROCESSES, logger)
# ---> 32 test_worker(breakout_args, global_agent, breakout_env, breakout_agent, N_PROCESSES, logger)
#      33 # process.start()
#      34 # processes.append(process)
#
# ~/Dropbox/Academic/PhD/Semesters/Spring19/RL/DRL/HWs/BLG604E-HW2-homework/DRL_HW2/blg604ehw2/a3c/train.py in test_worker(args, globalmodel, envfunc, agentfunc, lock, logger, monitor_path, render)
#     114     ### YOUR CODE HERE ###
#     115     import pdb;pdb.set_trace()
# --> 116     state = env.reset()
#     117     state = agent.serialize(state)
#     118     reward_sum = 0
#
# ~/Dropbox/Academic/PhD/Semesters/Spring19/RL/DRL/HWs/BLG604E-HW2-homework/DRL_HW2/blg604ehw2/utils.py in progress(self, index, reward)
#      97     def progress(self, index, reward):
#      98         """ Update progress with given index and best reward """
# ---> 99         self._progress.value = index
#     100         self._label.value = (
#     101             "{name}: {size}/{index}, Best reward: {reward}".format(
#
# ~/miniconda3/envs/blg604ehw2/lib/python3.7/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~/miniconda3/envs/blg604ehw2/lib/python3.7/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~/miniconda3/envs/blg604ehw2/lib/python3.7/site-packages/traitlets/traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1137             new=new_value,
#    1138             owner=self,
# -> 1139             type='change',
#    1140         ))
#    1141
#
# ~/miniconda3/envs/blg604ehw2/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     597             if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     598                 # Send new state to front-end
# --> 599                 self.send_state(key=name)
#     600         super(Widget, self).notify_change(change)
#     601
#
# ~/miniconda3/envs/blg604ehw2/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in send_state(self, key)
#     482             state, buffer_paths, buffers = _remove_buffers(state)
#     483             msg = {'method': 'update', 'state': state, 'buffer_paths': buffer_paths}
# --> 484             self._send(msg, buffers=buffers)
#     485
#     486     def get_state(self, key=None, drop_defaults=False):
#
# ~/miniconda3/envs/blg604ehw2/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in _send(self, msg, buffers)
#     727         """Sends a message to the model in the front-end."""
#     728         if self.comm is not None and self.comm.kernel is not None:
# --> 729             self.comm.send(data=msg, buffers=buffers)
#     730
#     731     def _repr_keys(self):
#
# ~/miniconda3/envs/blg604ehw2/lib/python3.7/site-packages/ipykernel/comm/comm.py in send(self, data, metadata, buffers)
#     119         """Send a message to the frontend-side version of this comm"""
#     120         self._publish_msg('comm_msg',
# --> 121             data=data, metadata=metadata, buffers=buffers,
#     122         )
#     123
#
# ~/miniconda3/envs/blg604ehw2/lib/python3.7/site-packages/ipykernel/comm/comm.py in _publish_msg(self, msg_type, data, metadata, buffers, **keys)
#      69             parent=self.kernel._parent_header,
#      70             ident=self.topic,
# ---> 71             buffers=buffers,
#      72         )
#      73
#
# ~/miniconda3/envs/blg604ehw2/lib/python3.7/site-packages/jupyter_client/session.py in send(self, stream, msg_or_type, content, parent, ident, buffers, track, header, metadata)
#     711         else:
#     712             msg = self.msg(msg_or_type, content=content, parent=parent,
# --> 713                            header=header, metadata=metadata)
#     714         if self.check_pid and not os.getpid() == self.pid:
#     715             get_logger().warning("WARNING: attempted to send message from fork\n%s",
#
# ~/miniconda3/envs/blg604ehw2/lib/python3.7/site-packages/jupyter_client/session.py in msg(self, msg_type, content, parent, header, metadata)
#     570         """
#     571         msg = {}
# --> 572         header = self.msg_header(msg_type) if header is None else header
#     573         msg['header'] = header
#     574         msg['msg_id'] = header['msg_id']
#
# ~/miniconda3/envs/blg604ehw2/lib/python3.7/site-packages/jupyter_client/session.py in msg_header(self, msg_type)
#     560
#     561     def msg_header(self, msg_type):
# --> 562         return msg_header(self.msg_id, msg_type, self.username, self.session)
#     563
#     564     def msg(self, msg_type, content=None, parent=None, header=None, metadata=None):
#
# ~/miniconda3/envs/blg604ehw2/lib/python3.7/site-packages/jupyter_client/session.py in msg_id(self)
#     510     def msg_id(self):
#     511         """always return new uuid"""
# --> 512         return new_id()
#     513
#     514     def _check_packers(self):
#
# ~/miniconda3/envs/blg604ehw2/lib/python3.7/site-packages/jupyter_client/session.py in new_id()
#     130     """
#     131     buf = os.urandom(16)
# --> 132     return u'-'.join(b2a_hex(x).decode('ascii') for x in (
#     133         buf[:4], buf[4:]
#     134     ))
#
# ~/miniconda3/envs/blg604ehw2/lib/python3.7/site-packages/jupyter_client/session.py in new_id()
#     130     """
#     131     buf = os.urandom(16)
# --> 132     return u'-'.join(b2a_hex(x).decode('ascii') for x in (
#     133         buf[:4], buf[4:]
#     134     ))
#
# ~/miniconda3/envs/blg604ehw2/lib/python3.7/bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# ~/miniconda3/envs/blg604ehw2/lib/python3.7/bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %%
# Plot the rewards from the logger
import matplotlib.pyplot as plt
plt.title("A3C Breakout Best Rewards")
plt.ylabel("reward")
plt.xlabel("time steps")
plt.plot(list(logger.time_steps), list(logger.best_reward))

# %%
# Save the best model's parameters
model_path = "monitor/Breakout/model_state_dict"
torch.save(logger.best_model.state_dict(), model_path)
